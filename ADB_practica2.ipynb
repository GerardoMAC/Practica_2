// %%
# include <iostream>
using namespace std;

float filas = 35;
float datos = 55627392;
float tamanioFila(float id, float numTrabajadores, float horario, float pacientes, float ramas, float salas, float elevadores, float edificios, float extension, float ranking ,float nomHospital,float direccion , float servicio ,float especialidad,float telefono ,float correo ,float pagweb, float nomDirector,float fecha);
float tamanioPagina(float tamaniodeFila, float filas);
float tamanioBD(float tamaniodePagina,float datos);

int main(){
	cout<< "\t\tPrograma que calcula el tamanio de una BASE DE DATOS en bytes.\n\n";
	cout<< "Conn diferentes atributos:\n"; cout<<"|id|numTrabajadores|horario|pacientes|\n|ramas|salas|elevadores|edificios|extension|\n|ranking|nomHospital|direccion|servicio|\n|especialidad|telefono|correo|pagweb|nomDirector|fecha|"<<endl;
	cout<< "35 filas"<<endl;
	cout<< "Con un total de 55,627,392 de registros.\n\n"<<endl;
	//4 bytes es el tamaño de la variable numerico
	float id = 4; float numTrabajadores = 4; float horario = 4; float pacientes = 4; 
	float ramas = 4; float salas = 4; float elevadores = 4; 
	float edificios = 4; float extension = 4; float ranking  = 4;
	//8 bytes es el tamaño de la variable  texto
	float nomHospital = 8; float direccion = 8; float servicio = 8; float especialidad = 8;
	float telefono = 8; float correo = 8; float pagweb = 8;  
	float nomDirector = 8; float fecha = 8;
	float tamaniodeFila;
	float tamaniodePagina;
	float tamaniodeBD;
	tamaniodeFila = tamanioFila(id,numTrabajadores,horario,pacientes,ramas,salas,elevadores,edificios,extension,ranking,nomHospital,direccion,servicio,especialidad,telefono,correo,pagweb,nomDirector,fecha);
	// tamaño de la fila
	cout<<"El tamanio de una fila es: "<<tamaniodeFila<<" bytes"<<endl;
	//Tamaño de la página
	tamaniodePagina = tamanioPagina(tamaniodeFila,filas);
	cout<< "El tamanio de la pagina es: "<<tamaniodePagina<<" bytes"<<endl;
	//Tamaño de la BD
	tamaniodeBD = tamanioBD(tamaniodeBD, datos);
	 cout<< "El tamanio de la base de datos es: "<<tamaniodeBD<<" bytes"<<endl;

}
//Tamaño de la fila
float tamanioFila(float id, float numTrabajadores, float horario, float pacientes, float ramas, float salas, float elevadores, float edificios, float extension, float ranking ,float nomHospital,float direccion , float servicio ,float especialidad,float telefono ,float correo ,float pagweb, float nomDirector,float fecha){
	float totalFila;
	totalFila = id+numTrabajadores+horario+pacientes+ramas+salas+elevadores+edificios+extension+ranking+nomHospital+direccion+ servicio+ especialidad+telefono+correo+pagweb+nomDirector+fecha; 
    return totalFila;
}

//Tamaño de la pagina
float tamanioPagina(float tamaniodeFila, float filas){

	return tamaniodeFila * filas;
	
}
//Tamaña de la base de datos
float tamanioBD(float tamaniodePagina,float datos){
	return tamaniodePagina * datos;
	
}
